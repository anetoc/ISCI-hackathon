# %% [markdown]
# # ISCI D0 — Movement (M) + Reproducibility (R) + baselines
#
# **Built with Claude: Life Sciences** hackathon seed notebook.
#
# ## Prerequisites
#
# 1. Download data to `data/` (see README.md)
# 2. `uv sync`
# 3. Implement stubs in `isci/` (or run from Claude for Life Sciences)
#
# ## D0 goals
#
# - Load `GWCD4i.DE_stats.h5ad`
# - Build axis vectors from `config/axes.yaml`
# - Compute M and R components
# - Run DE-magnitude baselines
# - Ground-truth recovery AUROC (canonical controllers)

# %%
# from pathlib import Path
# import anndata as ad
# from isci.axes import load_axes_config, build_axis_vectors
# from isci.movement import compute_movement
# from isci.repro import compute_reproducibility
# from isci.baselines import de_magnitude_baseline
# from isci.validate import ground_truth_recovery

# de = ad.read_h5ad(Path("../data/GWCD4i.DE_stats.h5ad"))
# config = load_axes_config(Path("../config/axes.yaml"))
# TODO: implement in Claude Science build
